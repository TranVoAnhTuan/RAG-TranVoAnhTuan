# %%
import base64
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage

def encode_image(image_path):
    """Hàm đọc và mã hóa ảnh sang chuỗi Base64."""
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

def main():
    # 1. Khởi tạo mô hình Qwen 3.5
    # Lưu ý: Cần chắc chắn phiên bản qwen3.5 bạn pull về có hỗ trợ Vision
    chat = ChatOllama(model="qwen3.5:2b", temperature=0, keep_alive='0s')

    # 2. Cung cấp đường dẫn tới file ảnh của bạn
    image_path = "/home/jacktran/Downloads/draft/download.jpeg" # Thay đổi tên file này cho phù hợp
    
    try:
        base64_image = encode_image(image_path)
    except FileNotFoundError:
        print(f"Lỗi: Không tìm thấy file ảnh '{image_path}'. Vui lòng kiểm tra lại đường dẫn.")
        return

    # 3. Tạo tin nhắn đa phương thức (Multimodal Message)
    messages = [
        HumanMessage(
            content=[
                {
                    "type": "text", 
                    "text": "Hãy miêu tả chi tiết những gì có trong bức ảnh này bằng tiếng Việt."
                },
                {
                    "type": "image_url",
                    "image_url": {
                        # Định dạng MIME. Đổi thành image/png nếu là ảnh PNG.
                        "url": f"data:image/jpeg;base64,{base64_image}" 
                    },
                },
            ]
        )
    ]

    # 4. Gửi yêu cầu tới Ollama và xử lý kết quả
    print("Đang gửi ảnh tới mô hình, vui lòng chờ...")
    try:
        response = chat.invoke(messages)
        print("\n=== KẾT QUẢ ĐẦU RA ===")
        print(response.content)
    except Exception as e:
        print(f"\nLỗi trong quá trình xử lý: {e}")

if __name__ == "__main__":
    main()

# %%
import hashlib

def get_file_hash(file_path):
    hasher = hashlib.sha256()

    with open(file_path, 'rb') as f:
        while chunk := f.read(8192):
            hasher.update(chunk)

    return hasher.hexdigest()

import sqlite3

conn = sqlite3.connect("files.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS files (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    file_name TEXT,
    file_hash TEXT UNIQUE
)
""")

conn.commit()

def save_file(file_name, file_hash):
    try:
        cursor.execute(
            "INSERT INTO files (file_name, file_hash) VALUES (?, ?)",
            (file_name, file_hash)
        )
        conn.commit()
        return True
    except sqlite3.IntegrityError:
        return False  # file đã tồn tại

def file_exists(file_hash):
    cursor.execute("SELECT 1 FROM files WHERE file_hash = ?", (file_hash,))
    return cursor.fetchone() is not None

file_path = "/home/jacktran/RAG/experiment/rag_agentic_system/1.pdf"

file_hash = get_file_hash(file_path)

if file_exists(file_hash):
    print("File đã tồn tại ❌")
else:
    save_file(file_path, file_hash)
    print("File mới, đã lưu ✅")
# Out:
# File đã tồn tại ❌

# %%
import json

def update_questions():
    input_file = "testset.json"
    output_file = "testset_updated.json"
    
    # Cụm từ tiếng Anh muốn thêm vào
    prefix = "According to the document, "

    # 1. Đọc file JSON gốc
    try:
        with open(input_file, "r", encoding="utf-8") as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"❌ Không tìm thấy file {input_file}")
        return

    # 2. Lặp qua từng item và cập nhật question
    for item in data:
        if "question" in item and isinstance(item["question"], str):
            original_q = item["question"].strip()
            
            if original_q:
                # Viết thường chữ cái đầu tiên của câu hỏi cũ (tuỳ chọn để câu văn tự nhiên hơn)
                first_char = original_q[0].lower()
                rest = original_q[1:]
                
                # Nối chuỗi
                item["question"] = f"{prefix}{first_char}{rest}"

    # 3. Lưu lại ra file mới
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4, ensure_ascii=False)

    print(f"✅ Đã xử lý {len(data)} câu hỏi và lưu vào '{output_file}'")

if __name__ == "__main__":
    update_questions()
# Out:
# ✅ Đã xử lý 67 câu hỏi và lưu vào 'testset_updated.json'

# %%
import json

def fix_data(input_file, output_file):
    with open(input_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    for item in data:
        # Nếu thiếu "answer"
        if "answer" not in item:
            item["answer"] = ""

        # Nếu thiếu "model_citations"
        if "model_citations" not in item:
            item["model_citations"] = [
                {
                    "Header_1": "",
                    "Header_2": "",
                    "Header_3": ""
                }
            ]

    # Ghi lại file
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)


# dùng
fix_data("/home/jacktran/RAG/experiment/rag_agentic_system/testset_with_answers.json", "/home/jacktran/RAG/experiment/rag_agentic_system/testset_with_answers.json")

# %%
import json

input_file = "testset_updated.json"
output_file = "output.jsonl"

with open(input_file, "r", encoding="utf-8") as f:
    data = json.load(f)

with open(output_file, "w", encoding="utf-8") as f:
    for item in data:
        new_item = {
            "inputs_1": item.get("question", ""),
            "outputs_1": item.get("ground_truth", "")
        }
        f.write(json.dumps(new_item, ensure_ascii=False) + "\n")

print("Done!")
# Out:
# Done!
