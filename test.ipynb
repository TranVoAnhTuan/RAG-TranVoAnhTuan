# %% [markdown]
# # path

# %%
source_directory = "/home/jacktran/RAG/experiment/files/"
target_directory = "/home/jacktran/RAG/experiment/target_files/"
csv_file = "/home/jacktran/RAG/experiment/processed/pdf_text.csv"

MODEL_ID = "panalexeu/xlm-roberta-ua-distilled"

# %% [markdown]
# # import

# %%
import os
import pandas as pd
import pymupdf

# %%
def extract_pdf(pdf_path, target_path):
    doc = pymupdf.open(pdf_path)
    with open(target_path, "wb") as out:
        for page in doc:
            text = page.get_text().encode("utf-8")
            out.write(text)
            out.write(bytes((12,)))

# %%
def extract_all_in_directory(source: str, target: str) -> None:
    if not os.path.exists(target):
        os.mkdir(target)

    for file in os.listdir(source):
        if file.endswith(".pdf"):
            file_path = os.path.join(source, file)
            target_file= file.split(".")[0] + ".txt"
            target_file_path = os.path.join(target, target_file)
            extract_pdf(file_path, target_file_path)
            print(f"extract from {file_path} to {target_file_path}")

# %%
extract_all_in_directory(source_directory, target_directory)
# Out:
# extract from /home/jacktran/RAG/experiment/files/927ac79f-30b6-420c-af2f-9229ba129bdf.pdf to /home/jacktran/RAG/experiment/target_files/927ac79f-30b6-420c-af2f-9229ba129bdf.txt
# extract from /home/jacktran/RAG/experiment/files/SSI_Q3_25_a82298dac6.pdf to /home/jacktran/RAG/experiment/target_files/SSI_Q3_25_a82298dac6.txt
# extract from /home/jacktran/RAG/experiment/files/Baocaocapnhat_VPB_Q3_VN.pdf to /home/jacktran/RAG/experiment/target_files/Baocaocapnhat_VPB_Q3_VN.txt
# extract from /home/jacktran/RAG/experiment/files/5fa639a7-4e66-495c-9e6f-22732ac748f4.pdf to /home/jacktran/RAG/experiment/target_files/5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# extract from /home/jacktran/RAG/experiment/files/download-with-token (1).pdf to /home/jacktran/RAG/experiment/target_files/download-with-token (1).txt
# extract from /home/jacktran/RAG/experiment/files/3ac90064-2e23-43cc-9e7f-6b9ea653b552.pdf to /home/jacktran/RAG/experiment/target_files/3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# extract from /home/jacktran/RAG/experiment/files/5641fb20-d894-499c-8b68-8477d24c992f.pdf to /home/jacktran/RAG/experiment/target_files/5641fb20-d894-499c-8b68-8477d24c992f.txt

# %% [markdown]
# # Cleaning

# %%
def cleaning(serie: pd.Series) -> pd.Series:
    return (
        serie
        .str.replace(r'\n{2,}', '. ', regex=True)
        .str.replace(r'[ \t\r\n]+', ' ', regex=True)
        .str.replace(' . ', '. ') 
        .str.strip()      
    )

# %%
df = pd.DataFrame(columns = ["file", "text"])
for file in os.listdir(target_directory):
    with open(target_directory + file, 'r', encoding= "UTF-8") as f:
        text = f.read()        
        row = {'file': file, 'text': text}
        df_tmp = pd.DataFrame([row])
        df_tmp["text"] = cleaning(df_tmp["text"])
        df = pd.concat([df, df_tmp], ignore_index = True)

# %%
df
# Out:
#                                        file  \
# 0                  SSI_Q3_25_a82298dac6.txt
# 1  5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# 2  927ac79f-30b6-420c-af2f-9229ba129bdf.txt
# 3  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 4                  VCB_cap-nhat_ACBS_10.txt
# 5               download-with-token (1).txt
# 6  3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# 7               Baocaocapnhat_VPB_Q3_VN.txt
#
#                                                 text
# 0  Giá mục tiêu 2026: % tăng giá: Cập nhật: TRIỂN...
# 1  BỘ GIÁO DỤC VÀ ĐÀO TẠO CỘNG HÒA XÃ HÔ...
# 2  BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN...
# 3  1 BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NH...
# 4  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...
# 5  BÁO CÁO PHÂN TÍCH KĨ THUẬT ACB: MUA – 26.000 V...
# 6  BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN...
# 7  Báo cáo cập nhật Ngân hàng TMCP Việt Nam Thịnh...

# %%
df.to_csv(csv_file)

# %% [markdown]
# # Chunking

# %%
from transformers import AutoTokenizer
MODEL_ID = "intfloat/multilingual-e5-large-instruct"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

df = pd.read_csv(csv_file, index_col = 0)
df['n_tokens'] = df['text'].apply(lambda x: len(tokenizer.encode(x)))
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Token indices sequence length is longer than the specified maximum sequence length for this model (2616 > 512). Running this sequence through the model will result in indexing errors

# %%
df
# Out:
#                                        file  \
# 0                  SSI_Q3_25_a82298dac6.txt
# 1  5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# 2  927ac79f-30b6-420c-af2f-9229ba129bdf.txt
# 3  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 4                  VCB_cap-nhat_ACBS_10.txt
# 5               download-with-token (1).txt
# 6  3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# 7               Baocaocapnhat_VPB_Q3_VN.txt
#
#                                                 text  n_tokens
# 0  Giá mục tiêu 2026: % tăng giá: Cập nhật: TRIỂN...      2616
# 1  BỘ GIÁO DỤC VÀ ĐÀO TẠO CỘNG HÒA XÃ HÔ...       886
# 2  BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN...       251
# 3  1 BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NH...      1704
# 4  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      6556
# 5  BÁO CÁO PHÂN TÍCH KĨ THUẬT ACB: MUA – 26.000 V...       987
# 6  BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN...      1231
# 7  Báo cáo cập nhật Ngân hàng TMCP Việt Nam Thịnh...      6850

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

def chunking_with_metadata(file_name, full_text, max_token=500):
    pages = full_text.split('\x0c')
    chunks_with_metadata = []
    current_chunk_sentences = []
    current_tokens = 0
    start_page = 1 

    for i, page_content in enumerate(pages):
        page_num = i + 1
        sentences = [s.strip() for s in page_content.split('. ') if s.strip()]
        
        for sent in sentences:
            sent_with_dot = sent + ". "
            token_ids = tokenizer.encode(sent_with_dot, add_special_tokens=False, truncation=True, max_length=1024)
            token_len = len(token_ids)
            
            if token_len > max_token:
                if current_chunk_sentences:
                    chunks_with_metadata.append({
                        'file': file_name,
                        'text': " ".join(current_chunk_sentences).strip(),
                        'page': f"{start_page}-{page_num}" if start_page != page_num else page_num
                    })
                    current_chunk_sentences = []
                    current_tokens = 0

                sub_chunks = [token_ids[i:i + max_token] for i in range(0, token_len, max_token)]
                for sub in sub_chunks:
                    chunks_with_metadata.append({
                        'file': file_name,
                        'text': tokenizer.decode(sub),
                        'page': page_num
                    })
                start_page = page_num
                continue

            if current_tokens + token_len > max_token:
                chunks_with_metadata.append({
                    'file': file_name,
                    'text': " ".join(current_chunk_sentences).strip(),
                    'page': f"{start_page}-{page_num}" if start_page != page_num else page_num
                })
                
                last_sentence = current_chunk_sentences[-1] if current_chunk_sentences else ""
                current_chunk_sentences = [last_sentence, sent] if last_sentence else [sent]
                current_tokens = len(tokenizer.encode(last_sentence + ". " + sent_with_dot, add_special_tokens=False, truncation=True))
                start_page = page_num
            else:
                current_chunk_sentences.append(sent)
                current_tokens += token_len

    if current_chunk_sentences:
        chunks_with_metadata.append({
            'file': file_name, 
            'text': " ".join(current_chunk_sentences).strip(),
            'page': f"{start_page}-{len(pages)}" if start_page != len(pages) else start_page
        })
        
    return chunks_with_metadata


all_records = []
for _, row in df.iterrows():
    if row['text']:
        res = chunking_with_metadata(row['file'], row['text'])
        all_records.extend(res)

df_vector = pd.DataFrame(all_records)

# %%
df_vector
# Out:
#                                         file  \
# 0                   SSI_Q3_25_a82298dac6.txt
# 1                   SSI_Q3_25_a82298dac6.txt
# 2                   SSI_Q3_25_a82298dac6.txt
# 3                   SSI_Q3_25_a82298dac6.txt
# 4                   SSI_Q3_25_a82298dac6.txt
# 5                   SSI_Q3_25_a82298dac6.txt
# 6                   SSI_Q3_25_a82298dac6.txt
# 7   5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# 8   5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# 9   5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# 10  927ac79f-30b6-420c-af2f-9229ba129bdf.txt
# 11  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 12  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 13  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 14  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 15                  VCB_cap-nhat_ACBS_10.txt
# 16                  VCB_cap-nhat_ACBS_10.txt
# 17                  VCB_cap-nhat_ACBS_10.txt
# 18                  VCB_cap-nhat_ACBS_10.txt
# 19                  VCB_cap-nhat_ACBS_10.txt
# 20                  VCB_cap-nhat_ACBS_10.txt
# 21                  VCB_cap-nhat_ACBS_10.txt
# 22                  VCB_cap-nhat_ACBS_10.txt
# 23                  VCB_cap-nhat_ACBS_10.txt
# 24                  VCB_cap-nhat_ACBS_10.txt
# 25                  VCB_cap-nhat_ACBS_10.txt
# 26                  VCB_cap-nhat_ACBS_10.txt
# 27                  VCB_cap-nhat_ACBS_10.txt
# 28                  VCB_cap-nhat_ACBS_10.txt
# 29                  VCB_cap-nhat_ACBS_10.txt
# 30                  VCB_cap-nhat_ACBS_10.txt
# 31                  VCB_cap-nhat_ACBS_10.txt
# 32                  VCB_cap-nhat_ACBS_10.txt
# 33               download-with-token (1).txt
# 34               download-with-token (1).txt
# 35               download-with-token (1).txt
# 36  3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# 37  3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# 38  3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# 39               Baocaocapnhat_VPB_Q3_VN.txt
# 40               Baocaocapnhat_VPB_Q3_VN.txt
# 41               Baocaocapnhat_VPB_Q3_VN.txt
# 42               Baocaocapnhat_VPB_Q3_VN.txt
# 43               Baocaocapnhat_VPB_Q3_VN.txt
# 44               Baocaocapnhat_VPB_Q3_VN.txt
# 45               Baocaocapnhat_VPB_Q3_VN.txt
# 46               Baocaocapnhat_VPB_Q3_VN.txt
# 47               Baocaocapnhat_VPB_Q3_VN.txt
# 48               Baocaocapnhat_VPB_Q3_VN.txt
# 49               Baocaocapnhat_VPB_Q3_VN.txt
# 50               Baocaocapnhat_VPB_Q3_VN.txt
# 51               Baocaocapnhat_VPB_Q3_VN.txt
# 52               Baocaocapnhat_VPB_Q3_VN.txt
# 53               Baocaocapnhat_VPB_Q3_VN.txt
# 54               Baocaocapnhat_VPB_Q3_VN.txt
# 55               Baocaocapnhat_VPB_Q3_VN.txt
# 56               Baocaocapnhat_VPB_Q3_VN.txt
# 57               Baocaocapnhat_VPB_Q3_VN.txt
#
#                                                  text   page
# 0   Giá mục tiêu 2026: % tăng giá: Cập nhật: TRIỂN...      1
# 1   Sau tăng vốn cổphiếu hiện đang giao dịch ởmức ...    1-2
# 2   Lũy kế9 tháng đầu năm 2025, doanh thu của SSI ...      2
# 3   Danh mục tựdoanh tăng gần 5.000 tỷso với báo c...    2-4
# 4   P/B Giá dự phóng (VND) Tỷ trọng Giá dự phóng t...    4-5
# 5   Các chuyên viên phân tích nghiên cứu phụtrách ...      5
# 6   SSI CTCP Chứng khoán SSI Khuyến nghị Định nghĩ...      5
# 7   BỘ GIÁO DỤC VÀ ĐÀO TẠO CỘNG HÒA XÃ HÔ...      1
# 8   Đối chiếu với các quy định trên, thời hạn tối ...    1-2
# 9   Nơi nhận: KT HIỆU TRƯỞNG - Hiệu trưởng (bể ba...      2
# 10  BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN...      1
# 11  1 BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NH...      1
# 12  - Ban Giám đốc Công an tỉnh, lãnh đạo, chỉ huy...    1-2
# 13  4 Chương trình TT Thời gian Nội dung Người / đ...    2-3
# 14  5.3 Đoàn Thanh niên, Hội sinh viên - Cử 06 nữ ...    3-4
# 15  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...    1-2
# 16  Chất lượng tài sản duy trì ở mức tốt Tỷ lệ nợ ...      2
# 17  Cao Việt Hùng, CFA (028) 7300 7000 (ext: 1049)...      2
# 18  9 31,061 ROA 1.4% 1.7% 1.6% 1.6% 1.5% 1.4% ROE...      2
# 19  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      3
# 20  19 3Q19 4Q19 1Q20 2Q20 3Q20 4Q20 1Q21 2Q21 3Q2...      3
# 21  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      4
# 22  Q22 3Q22 4Q22 1Q23 2Q23 3Q23 4Q23 1Q24 2Q24 3Q...      4
# 23  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      5
# 24  1% 2.0% 23.9% 13.3% 14.0 3.3 TPB HOSE 48,130 4...      5
# 25  1% 1.5% 16.8% 12.2% 8.4 1.3 Nguồn: Fiinpro-X, ...      5
# 26  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      6
# 27  95,698 1,514,665 1,696,425 1,933,924 Tăng trưở...      6
# 28  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...    6-8
# 29  BÁN : tổng lợi nhuận từ cổ phiếu (bao gồm suất...      8
# 30  ACBS sẽ không xem những người nhận báo cáo,khô...      8
# 31  Bản báo cáo có chứa đựng các giả định,quan điể...      8
# 32  Trong trường hợp quốc gia của nhà đầu tư nghiê...      8
# 33  BÁO CÁO PHÂN TÍCH KĨ THUẬT ACB: MUA – 26.000 V...      1
# 34  Ngưỡng hỗ trợ gần nhất là vùng đáy cũ, tương đ...    1-2
# 35  Mọi hành động sao chép một phần hoặc toàn bộ n...      2
# 36  BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN...      1
# 37  Tất cả thí sinh phải đảm bảo đủ điều kiện về s...    1-2
# 38  Thời gian học: buổi tối các ngày trong tuần ho...    2-3
# 39  Báo cáo cập nhật Ngân hàng TMCP Việt Nam Thịnh...    1-2
# 40  Thanh khoản bất động sản giảm Theo báo cáo của...    2-3
# 41  Trái lại, NIM bình quân trong kỳ tiếp tục sụt ...      3
# 42  • Tổng kết lại, ngân hàng ghi nhận 7.257 tỷđồn...    3-4
# 43  Nguyên nhân tăng trưởng mạnh hơn so với trung ...      4
# 44  Chúng tôi dự báo rằng, tỷ trọng này sẽ tiếp tụ...    4-5
# 45  Rủi ro thanh khoản có thể gia tăng nếu dư nợ l...      5
# 46  • Tỷ lệ đòn bẩy VCSH/TTS của VPB tăng nhẹ lên ...    5-6
# 47  Lũy kế9 tháng đầu năm, công ty ghi nhận lợi nh...      6
# 48  Có hệ sinh thái ngân hàng mẹ đằng sau giúp côn...    6-7
# 49  Quy mô CASA tăng cao kỷ lục nhưng cạnh tranh g...      7
# 50  Tỷlệbao phủnợxấu ởmức thấp cho thấy bộđệm dựph...    7-8
# 51  Trong đó: • Tín dụng: Chúng tôi dựbáo tăng trư...      8
# 52  • Dựphòng: Tổng chi phí dựphòng rủi ro tín dụn...    8-9
# 53  Trang 9 Ngân hàng TMCP Việt Nam Thịnh Vượng (H...   9-10
# 54  Trang 10 Ngân hàng TMCP Việt Nam Thịnh Vượng (...     10
# 55  +286 đcb CIR 23.0% -499 đcb 22.0% -291 đcb -46...     10
# 56  Trang 11 Ngân hàng TMCP Việt Nam Thịnh Vượng (...  10-12
# 57  Mọi hành vi sao chép, in ấn khi không có sựcho...     12

# %%
df_vector['n_tokens'] = df_vector.text.apply(lambda x: len(tokenizer.encode(x)))
df_vector
# Out:
#                                         file  \
# 0                   SSI_Q3_25_a82298dac6.txt
# 1                   SSI_Q3_25_a82298dac6.txt
# 2                   SSI_Q3_25_a82298dac6.txt
# 3                   SSI_Q3_25_a82298dac6.txt
# 4                   SSI_Q3_25_a82298dac6.txt
# 5                   SSI_Q3_25_a82298dac6.txt
# 6                   SSI_Q3_25_a82298dac6.txt
# 7   5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# 8   5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# 9   5fa639a7-4e66-495c-9e6f-22732ac748f4.txt
# 10  927ac79f-30b6-420c-af2f-9229ba129bdf.txt
# 11  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 12  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 13  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 14  5641fb20-d894-499c-8b68-8477d24c992f.txt
# 15                  VCB_cap-nhat_ACBS_10.txt
# 16                  VCB_cap-nhat_ACBS_10.txt
# 17                  VCB_cap-nhat_ACBS_10.txt
# 18                  VCB_cap-nhat_ACBS_10.txt
# 19                  VCB_cap-nhat_ACBS_10.txt
# 20                  VCB_cap-nhat_ACBS_10.txt
# 21                  VCB_cap-nhat_ACBS_10.txt
# 22                  VCB_cap-nhat_ACBS_10.txt
# 23                  VCB_cap-nhat_ACBS_10.txt
# 24                  VCB_cap-nhat_ACBS_10.txt
# 25                  VCB_cap-nhat_ACBS_10.txt
# 26                  VCB_cap-nhat_ACBS_10.txt
# 27                  VCB_cap-nhat_ACBS_10.txt
# 28                  VCB_cap-nhat_ACBS_10.txt
# 29                  VCB_cap-nhat_ACBS_10.txt
# 30                  VCB_cap-nhat_ACBS_10.txt
# 31                  VCB_cap-nhat_ACBS_10.txt
# 32                  VCB_cap-nhat_ACBS_10.txt
# 33               download-with-token (1).txt
# 34               download-with-token (1).txt
# 35               download-with-token (1).txt
# 36  3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# 37  3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# 38  3ac90064-2e23-43cc-9e7f-6b9ea653b552.txt
# 39               Baocaocapnhat_VPB_Q3_VN.txt
# 40               Baocaocapnhat_VPB_Q3_VN.txt
# 41               Baocaocapnhat_VPB_Q3_VN.txt
# 42               Baocaocapnhat_VPB_Q3_VN.txt
# 43               Baocaocapnhat_VPB_Q3_VN.txt
# 44               Baocaocapnhat_VPB_Q3_VN.txt
# 45               Baocaocapnhat_VPB_Q3_VN.txt
# 46               Baocaocapnhat_VPB_Q3_VN.txt
# 47               Baocaocapnhat_VPB_Q3_VN.txt
# 48               Baocaocapnhat_VPB_Q3_VN.txt
# 49               Baocaocapnhat_VPB_Q3_VN.txt
# 50               Baocaocapnhat_VPB_Q3_VN.txt
# 51               Baocaocapnhat_VPB_Q3_VN.txt
# 52               Baocaocapnhat_VPB_Q3_VN.txt
# 53               Baocaocapnhat_VPB_Q3_VN.txt
# 54               Baocaocapnhat_VPB_Q3_VN.txt
# 55               Baocaocapnhat_VPB_Q3_VN.txt
# 56               Baocaocapnhat_VPB_Q3_VN.txt
# 57               Baocaocapnhat_VPB_Q3_VN.txt
#
#                                                  text   page  n_tokens
# 0   Giá mục tiêu 2026: % tăng giá: Cập nhật: TRIỂN...      1       489
# 1   Sau tăng vốn cổphiếu hiện đang giao dịch ởmức ...    1-2       492
# 2   Lũy kế9 tháng đầu năm 2025, doanh thu của SSI ...      2       481
# 3   Danh mục tựdoanh tăng gần 5.000 tỷso với báo c...    2-4       467
# 4   P/B Giá dự phóng (VND) Tỷ trọng Giá dự phóng t...    4-5       497
# 5   Các chuyên viên phân tích nghiên cứu phụtrách ...      5       481
# 6   SSI CTCP Chứng khoán SSI Khuyến nghị Định nghĩ...      5       171
# 7   BỘ GIÁO DỤC VÀ ĐÀO TẠO CỘNG HÒA XÃ HÔ...      1       475
# 8   Đối chiếu với các quy định trên, thời hạn tối ...    1-2       491
# 9   Nơi nhận: KT HIỆU TRƯỞNG - Hiệu trưởng (bể ba...      2       109
# 10  BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN...      1       245
# 11  1 BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NH...      1       474
# 12  - Ban Giám đốc Công an tỉnh, lãnh đạo, chỉ huy...    1-2       415
# 13  4 Chương trình TT Thời gian Nội dung Người / đ...    2-3       471
# 14  5.3 Đoàn Thanh niên, Hội sinh viên - Cử 06 nữ ...    3-4       373
# 15  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...    1-2       478
# 16  Chất lượng tài sản duy trì ở mức tốt Tỷ lệ nợ ...      2       245
# 17  Cao Việt Hùng, CFA (028) 7300 7000 (ext: 1049)...      2       502
# 18  9 31,061 ROA 1.4% 1.7% 1.6% 1.6% 1.5% 1.4% ROE...      2       153
# 19  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      3       502
# 20  19 3Q19 4Q19 1Q20 2Q20 3Q20 4Q20 1Q21 2Q21 3Q2...      3       328
# 21  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      4       502
# 22  Q22 3Q22 4Q22 1Q23 2Q23 3Q23 4Q23 1Q24 2Q24 3Q...      4       236
# 23  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      5       502
# 24  1% 2.0% 23.9% 13.3% 14.0 3.3 TPB HOSE 48,130 4...      5       502
# 25  1% 1.5% 16.8% 12.2% 8.4 1.3 Nguồn: Fiinpro-X, ...      5        23
# 26  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...      6       502
# 27  95,698 1,514,665 1,696,425 1,933,924 Tăng trưở...      6       307
# 28  Cập nhật VCB – KHẢ QUAN 10/12/2025 Phòng Phân ...    6-8       471
# 29  BÁN : tổng lợi nhuận từ cổ phiếu (bao gồm suất...      8       446
# 30  ACBS sẽ không xem những người nhận báo cáo,khô...      8       489
# 31  Bản báo cáo có chứa đựng các giả định,quan điể...      8       477
# 32  Trong trường hợp quốc gia của nhà đầu tư nghiê...      8       258
# 33  BÁO CÁO PHÂN TÍCH KĨ THUẬT ACB: MUA – 26.000 V...      1       451
# 34  Ngưỡng hỗ trợ gần nhất là vùng đáy cũ, tương đ...    1-2       445
# 35  Mọi hành động sao chép một phần hoặc toàn bộ n...      2       140
# 36  BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN...      1       492
# 37  Tất cả thí sinh phải đảm bảo đủ điều kiện về s...    1-2       435
# 38  Thời gian học: buổi tối các ngày trong tuần ho...    2-3       338
# 39  Báo cáo cập nhật Ngân hàng TMCP Việt Nam Thịnh...    1-2       473
# 40  Thanh khoản bất động sản giảm Theo báo cáo của...    2-3       470
# 41  Trái lại, NIM bình quân trong kỳ tiếp tục sụt ...      3       326
# 42  • Tổng kết lại, ngân hàng ghi nhận 7.257 tỷđồn...    3-4       456
# 43  Nguyên nhân tăng trưởng mạnh hơn so với trung ...      4       398
# 44  Chúng tôi dự báo rằng, tỷ trọng này sẽ tiếp tụ...    4-5       486
# 45  Rủi ro thanh khoản có thể gia tăng nếu dư nợ l...      5       284
# 46  • Tỷ lệ đòn bẩy VCSH/TTS của VPB tăng nhẹ lên ...    5-6       496
# 47  Lũy kế9 tháng đầu năm, công ty ghi nhận lợi nh...      6       437
# 48  Có hệ sinh thái ngân hàng mẹ đằng sau giúp côn...    6-7       478
# 49  Quy mô CASA tăng cao kỷ lục nhưng cạnh tranh g...      7       341
# 50  Tỷlệbao phủnợxấu ởmức thấp cho thấy bộđệm dựph...    7-8       437
# 51  Trong đó: • Tín dụng: Chúng tôi dựbáo tăng trư...      8       491
# 52  • Dựphòng: Tổng chi phí dựphòng rủi ro tín dụn...    8-9       243
# 53  Trang 9 Ngân hàng TMCP Việt Nam Thịnh Vượng (H...   9-10       400
# 54  Trang 10 Ngân hàng TMCP Việt Nam Thịnh Vượng (...     10       502
# 55  +286 đcb CIR 23.0% -499 đcb 22.0% -291 đcb -46...     10        72
# 56  Trang 11 Ngân hàng TMCP Việt Nam Thịnh Vượng (...  10-12       478
# 57  Mọi hành vi sao chép, in ấn khi không có sựcho...     12       305

# %%
df_vector['n_tokens'].max()
# Out:
# np.int64(502)

# %% [markdown]
# # Embedding

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer(MODEL_ID)
# Out:
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 1119.44it/s, Materializing param=pooler.dense.weight]

# %%
def get_embedding(text: str):
    text = text.replace("\n", " ")
    return model.encode(text, normalize_embeddings=True).tolist()

df_vector["embeddings"] = df_vector["text"].apply(get_embedding)

# %%
import numpy as np

embeddings = np.array(df_vector["embeddings"].tolist())
embeddings.shape
# Out:
# (58, 1024)

# %% [markdown]
# # Test

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def query_top_n(user_query: str, df: pd.DataFrame, top_n: int = 5):
    instructional_query = f"query: {user_query}"
    
    query_vec = model.encode(instructional_query, normalize_embeddings=True).reshape(1, -1)
    
    doc_vecs = np.stack(df['embeddings'].values)
    
    scores = cosine_similarity(query_vec, doc_vecs)[0]
    
    top_indices = np.argsort(scores)[::-1][:top_n]
    
    results = []
    for idx in top_indices:
        results.append({
            "file_name": df.iloc[idx]['file'],
            "page": df.iloc[idx].get('page', 'N/A'),
            "text": df.iloc[idx]['text'],
            "score": round(float(scores[idx]), 4)
        })
    return results

results = query_top_n("Hội thảo Tham vấn về xây dựng các phương án phòng ngừa, ứng phó, bảo đảm an ninh môi trường biển của tỉnh Gia Lai được tổ chức vào thời gian và địa điểm cụ thể nào?", df_vector)

for res in results:
    print(f"[{res['score']}] File: {res['file_name']} (Trang: {res['page']})")
    print(f"Content: {res['text'][:200]}...")
    print("-" * 30)
# Out:
# [0.9124] File: 5641fb20-d894-499c-8b68-8477d24c992f.txt (Trang: 1)
# Content: 1 BỘ GIÁO DỤC VÀ ĐÀO TẠO TRƯỜNG ĐẠI HỌC QUY NHƠN CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM Độc lập - Tự do - Hạnh phúc Số: /KH-ĐHQN Gia Lai, ngày tháng 12 năm 2025 KẾ HOẠCH Tổ chức Hội thảo khoa học “Tham vấ...
# ------------------------------
# [0.9099] File: 5641fb20-d894-499c-8b68-8477d24c992f.txt (Trang: 1-2)
# Content: - Ban Giám đốc Công an tỉnh, lãnh đạo, chỉ huy PV01, PC03, PA02, PA03, PA04, chỉ huy 15 Công an xã, phường ven biển, Ban chỉ huy Bộ đội Biên phòng thuộc Bộ Chỉ huy Quân sự tỉnh - Đại diện lãnh đạo Việ...
# ------------------------------
# [0.8738] File: 5641fb20-d894-499c-8b68-8477d24c992f.txt (Trang: 2-3)
# Content: 4 Chương trình TT Thời gian Nội dung Người / đơn vị chủ trì thực hiện 1 13h30-14h00 Đón tiếp đại biểu, ổn định hội trường Trường Đại học Quy Nhơn + Công an tỉnh Gia Lai 2 14h00-14h10 Tuyên bố lý do, g...
# ------------------------------
# [0.8445] File: 5641fb20-d894-499c-8b68-8477d24c992f.txt (Trang: 3-4)
# Content: 5.3 Đoàn Thanh niên, Hội sinh viên - Cử 06 nữ và 02 nam sinh viên làm công tác đón tiếp, hỗ trợ phục vụ Hội thảo, gửi danh sách sinh viên về Phòng KHCN&HTQT trước ngày 17/12/2025 - Phối hợp với các đơ...
# ------------------------------
# [0.8247] File: 5fa639a7-4e66-495c-9e6f-22732ac748f4.txt (Trang: 2)
# Content: Nơi nhận: KT HIỆU TRƯỞNG - Hiệu trưởng (bể báo cáo); PHÓ HIỆU TRƯỞNG - Các khoa quản lý ngành (phối hợp t/h); - Phòng KT&BĐCL (thu nhận VB/CC NN); - Học viên cao học các khóa 24B, 25AB, 26A (để bi...
# ------------------------------

# %% [markdown]
# # Testing extraction

# %%
import pymupdf
import pandas as pd
import re
import statistics

def is_uppercase_ratio(text, threshold=0.8):
    letters = [c for c in text if c.isalpha()]
    if not letters:
        return False
    upper = [c for c in letters if c.isupper()]
    return len(upper) / len(letters) >= threshold



def parse_pdf(pdf_path):
    doc = pymupdf.open(pdf_path)

    lines = []

    for page_num, page in enumerate(doc, start=1):
        blocks = page.get_text("dict")["blocks"]

        for block in blocks:
            if "lines" not in block:
                continue

            for line in block["lines"]:
                text = "".join([s["text"] for s in line["spans"]]).strip()
                if not text:
                    continue

                span = line["spans"][0]

                lines.append({
                    "page": page_num,
                    "text": text,
                    "font_size": span["size"],
                    "font": span["font"],
                    "flags": span["flags"]
                })

    body_font_size = statistics.mode([l["font_size"] for l in lines])

    results = []

    current_heading = None
    current_body = []
    current_page = None

    for line in lines:
        text = line["text"]
        is_bold = "Bold" in line["font"] or (line["flags"] & 2)

        is_heading_candidate = (
            is_bold
            or line["font_size"] > body_font_size
            or re.match(r"^\d+[\.\)]", text)
            or is_uppercase_ratio(text)
        )

        if is_heading_candidate:
            if current_heading and current_body:
                results.append({
                    "page": current_page,
                    "heading": current_heading,
                    "body": " ".join(current_body).strip()
                })

            current_heading = text
            current_body = []
            current_page = line["page"]

        else:
            if current_heading:
                current_body.append(text)

    if current_heading and current_body:
        results.append({
            "page": current_page,
            "heading": current_heading,
            "body": " ".join(current_body).strip()
        })

    return pd.DataFrame(results)

# %%
pdf_path =  "/home/jacktran/RAG/experiment/files/927ac79f-30b6-420c-af2f-9229ba129bdf.pdf"

df = parse_pdf(pdf_path)
df
# Out:
#    page                               heading  \
# 0     1  năm học 2025-2026, đại học chính quy
# 1     1                             Nơi nhận:
# 2     1                     TS. Đinh Anh Tuấn
#
#                                                 body
# 0  Căn cứ Thông báo số 4567/TB-ĐHQN ngày 26/12/20...
# 1  - HT (để báo cáo); - Các Khoa (để thực hiện); ...
# 2                                           70 13 01

# %%
pdf_path =  "/home/jacktran/RAG/experiment/files/3ac90064-2e23-43cc-9e7f-6b9ea653b552.pdf"

df = parse_pdf(pdf_path)
df
# Out:
#    page                                            heading  \
# 0     1  Ngôn ngữ Anh, Công tác xã hội, Kế toán, Quản l...
# 1     1                                           Chỉ tiêu
# 2     1                 2. Đối tượng, điều kiện tuyển sinh
# 3     2                                3. Thủ tục dự tuyển
# 4     2                                               Lai.
# 5     2  4. Thời gian đào tạo, hình thức học và chuẩn đ...
# 6     2                                  5. Phí tuyển sinh
# 7     2                                 Thông tin liên hệ:
# 8     3                                                  3
# 9     3                                          Nơi nhận:
#
#                                                 body
# 0  Trường Đại học Quy Nhơn thông báo tuyển sinh đ...
# 1  1 Luật Xét kết quả học tập trung cấp, cao đẳng...
# 2  Đối tượng tuyển sinh là những người đã có bằng...
# 3  Thí sinh nộp 01 bộ hồ sơ giấy (trực tiếp hoặc ...
# 4  Hồ sơ gồm có: - Phiếu đăng ký xét tuyển; - Đối...
# 5  Thời gian đào tạo được xác định dựa trên trình...
# 6             Phí tuyển sinh: 400.000 đồng/thí sinh.
# 7  - Phòng Đào tạo (bộ phận Vừa làm vừa học), Phò...
# 8  Website: https://pdt.qnu.edu.vn - Phòng Kế hoạ...
# 9  - Hiệu trưởng (để báo cáo); - Phòng: KH-TC, CT...
